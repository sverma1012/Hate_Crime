# %%
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

# %% [markdown]
# ## Race

# %%
# import the sheet with the information on anti-race offenses

race = pd.read_excel('Table1_v2_2019.xls', sheet_name=6)

race
# Out:
#                                               Race  Incidents  Offenses  \
# 0                                       Anti-White        666       755
# 1                   Anti-Black or African American       1930      2314
# 2            Anti-American Indian or Alaska Native        119       126
# 3                                       Anti-Asian        158       205
# 4   Anti-Native Hawaiian or Other Pacific Islander         21        25
# 5                       Anti-Multiple Races, Group        134       171
# 6                                        Anti-Arab         95       122
# 7                          Anti-Hispanic or Latino        527       676
# 8               Anti-Other Race/Ethnicity/Ancestry        313       390
# 9                                            Total       3963      4784
# 10                           Single Bias Incidents       7103      8302
#
#     Victims1  Known\noffenders2
# 0        775                645
# 1       2391               1682
# ...

# %%
race.columns
# Out:
# Index(['Race', 'Incidents', 'Offenses', 'Victims1', 'Known\noffenders2'], dtype='object')

# %%
# Reassign column names

race.rename(columns={'Victims1':'Victims', 'Known\noffenders2':'Known_Offenders'}, inplace=True)

race.columns
# Out:
# Index(['Race', 'Incidents', 'Offenses', 'Victims', 'Known_Offenders'], dtype='object')

# %%
race
# Out:
#                                               Race  Incidents  Offenses  \
# 0                                       Anti-White        666       755
# 1                   Anti-Black or African American       1930      2314
# 2            Anti-American Indian or Alaska Native        119       126
# 3                                       Anti-Asian        158       205
# 4   Anti-Native Hawaiian or Other Pacific Islander         21        25
# 5                       Anti-Multiple Races, Group        134       171
# 6                                        Anti-Arab         95       122
# 7                          Anti-Hispanic or Latino        527       676
# 8               Anti-Other Race/Ethnicity/Ancestry        313       390
# 9                                            Total       3963      4784
# 10                           Single Bias Incidents       7103      8302
#
#     Victims  Known_Offenders
# 0       775              645
# 1      2391             1682
# ...

# %%
# export the edited dataframe

race.to_csv('race.csv', index=False)

# %% [markdown]
# ## Religion

# %%
# import the sheet with information about anti-religion offenses.

religion = pd.read_excel('Table1_v2.xls', sheet_name=5)

religion
# Out:
#                                          Religion  Incidents  Offenses  \
# 0                                     Anti-Jewish        953       995
# 1                                   Anti-Catholic         64        66
# 2                                 Anti-Protestant         24        24
# 3                           Anti-Islamic (Muslim)        176       219
# 4                             Anti-Other Religion         88       108
# 5                  Anti-Multiple Religions, Group         37        42
# 6                                     Anti-Mormon         12        14
# 7                          Anti-Jehovah's Witness          7         7
# 8   Anti-Eastern Orthodox (Russian, Greek, Other)         44        47
# 9                            Anti-Other Christian         49        60
# 10                                  Anti-Buddhist          5         5
# 11                                     Anti-Hindu          7         7
# ...

# %%
religion.columns
# Out:
# Index(['Religion', 'Incidents', 'Offenses', 'Victims1', 'Known\noffenders2'], dtype='object')

# %%
# Reassign column names

religion.rename(columns={'Victims1':'Victims', 'Known\noffenders2':'Known_Offenders'}, inplace=True)

religion.columns
# Out:
# Index(['Religion', 'Incidents', 'Offenses', 'Victims', 'Known_Offenders'], dtype='object')

# %%
religion
# Out:
#                                          Religion  Incidents  Offenses  \
# 0                                     Anti-Jewish        953       995
# 1                                   Anti-Catholic         64        66
# 2                                 Anti-Protestant         24        24
# 3                           Anti-Islamic (Muslim)        176       219
# 4                             Anti-Other Religion         88       108
# 5                  Anti-Multiple Religions, Group         37        42
# 6                                     Anti-Mormon         12        14
# 7                          Anti-Jehovah's Witness          7         7
# 8   Anti-Eastern Orthodox (Russian, Greek, Other)         44        47
# 9                            Anti-Other Christian         49        60
# 10                                  Anti-Buddhist          5         5
# 11                                     Anti-Hindu          7         7
# ...

# %%
# export the edited dataframe

religion.to_csv('religion.csv', index=False)
